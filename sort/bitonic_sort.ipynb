# %%
# !pip install Ninja
# Out:
# Requirement already satisfied: Ninja in /usr/local/lib/python3.11/dist-packages (1.11.1.3)

# %%
import os
import math

import torch
from torch.nn import functional as F
from torch.utils.cpp_extension import load_inline

# %%
import os
import math

import torch
from torch.nn import functional as F
from torch.utils.cpp_extension import load_inline

cuda_src = '''
__global__
void forward_kernel(float* A, int len, int j) {
  int t = blockIdx.x*blockDim.x + threadIdx.x;
  int l = t ^ j;
  int dir = t & len;

  if(t < l){
    if(((dir == 0) && A[t] > A[l]) || ((dir !=0) && A[t] < A[l])){
        float temp = A[t];
        A[t] = A[l];
        A[l] = temp;
    }
  }

  return;
}

torch::Tensor forward(torch::Tensor A) {
    int n = static_cast<int>(A.size(0));

    torch::Tensor O = A.clone();

    int num_threads = 1024;
    int num_blocks = n/1024;
    dim3 grid_dim(num_blocks);
    dim3 block_dim(num_threads);

    for(int len=2; len <= n; len *= 2){
        for(int j=len/2; j>0; j /= 2){
            forward_kernel<<<grid_dim, block_dim>>>(
                O.data_ptr<float>(),
                len,
                j
            );
        }
    }

    return O;
}
'''

cpp_src = 'torch::Tensor forward(torch::Tensor A);'

build_dir = 'cuda'
if not os.path.exists(build_dir):
    os.mkdir(build_dir)

os.environ['TORCH_CUDA_ARCH_LIST'] = "7.5"

bit_sort = load_inline(
    name='bit_sort',
    cpp_sources=cpp_src,
    cuda_sources=cuda_src,
    functions=['forward'],
    with_cuda=True,
    extra_cuda_cflags=["-arch=sm_75"],
    build_directory=f'./{build_dir}'
)

# %%
def generate_input(size: int, seed: int) -> torch.Tensor:
    """
    Generates random input tensor where elements are drawn from different distributions.

    Args:
        size: Total size of the final 1D tensor
        seed: Base seed for random generation

    Returns:
        1D tensor of size `size` containing flattened values from different distributions
    """
    # Calculate dimensions for a roughly square 2D matrix
    rows = int(size ** 0.5)  # Square root for roughly square shape
    cols = (size + rows - 1) // rows  # Ceiling division to ensure total size >= requested size

    gen = torch.Generator(device='cuda')
    result = torch.empty((rows, cols), device='cuda', dtype=torch.float32)

    # Different seed for each row!
    for i in range(rows):
        row_seed = seed + i
        gen.manual_seed(row_seed)

        # Generate values for this row with mean=row_seed
        result[i, :] = torch.randn(cols, device='cuda', dtype=torch.float32, generator=gen) + row_seed

    # Flatten and trim to exact size requested
    return result.flatten()[:size].contiguous()

# %%
sizes = [1024, 2048, 4096, 8192, 16384, 32768, 65536, 16777216]
seed = 4052
gen = torch.Generator(device='cuda')
gen.manual_seed(seed)

print('=== profiling vector add === ')
for size in sizes:
  print(f"------------ vector add on size {size} ------------------------------------")
  a = generate_input(size, seed)
  ref = torch.sort(a)[0]
  with torch.autograd.profiler.profile(use_cuda=True) as prof:
    result = bit_sort.forward(a)
  print(prof.key_averages().table(sort_by='cuda_time_total', row_limit=10))

#   print(result)
#   print(ref)
  print('attn values sanity check:', torch.allclose(result, ref, rtol=0, atol=1e-02))
# Out:
# === profiling vector add ===
# ------------ vector add on size 1024 ------------------------------------
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::clone        11.71%      31.880us        27.89%      75.923us      75.923us      39.000us        46.99%      83.000us      83.000us             1
#               aten::copy_         3.69%      10.042us         8.23%      22.414us      22.414us      26.000us        31.33%      26.000us      26.000us             1
#       aten::empty_strided         5.12%      13.939us         5.12%      13.939us      13.939us      18.000us        21.69%      18.000us      18.000us             1
#           cudaEventRecord         8.20%      22.325us         8.20%      22.325us       3.721us       0.000us         0.00%       0.000us       0.000us             6
#           cudaMemcpyAsync         4.55%      12.372us         4.55%      12.372us      12.372us       0.000us         0.00%       0.000us       0.000us             1
#          cudaLaunchKernel        59.99%     163.282us        59.99%     163.282us       2.969us       0.000us         0.00%       0.000us       0.000us            55
#     cudaDeviceSynchronize         6.74%      18.340us         6.74%      18.340us      18.340us       0.000us         0.00%       0.000us       0.000us             1
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 272.180us
# Self CUDA time total: 83.000us
#
# attn values sanity check: True
# ------------ vector add on size 2048 ------------------------------------
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::clone         8.37%      27.027us        21.66%      69.965us      69.965us      33.000us        44.00%      75.000us      75.000us             1
#               aten::copy_         3.12%      10.082us         7.06%      22.819us      22.819us      26.000us        34.67%      26.000us      26.000us             1
#       aten::empty_strided         3.65%      11.778us         3.65%      11.778us      11.778us      16.000us        21.33%      16.000us      16.000us             1
#           cudaEventRecord         6.15%      19.869us         6.15%      19.869us       3.311us       0.000us         0.00%       0.000us       0.000us             6
#           cudaMemcpyAsync         3.94%      12.737us         3.94%      12.737us      12.737us       0.000us         0.00%       0.000us       0.000us             1
#          cudaLaunchKernel        71.89%     232.193us        71.89%     232.193us       3.518us       0.000us         0.00%       0.000us       0.000us            66
#     cudaDeviceSynchronize         2.88%       9.306us         2.88%       9.306us       9.306us       0.000us         0.00%       0.000us       0.000us             1
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 322.992us
# Self CUDA time total: 75.000us
#
# attn values sanity check: True
# ------------ vector add on size 4096 ------------------------------------
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::clone         6.22%      19.249us        20.17%      62.378us      62.378us      24.000us        36.36%      66.000us      66.000us             1
#               aten::copy_         3.29%      10.160us         7.61%      23.520us      23.520us      27.000us        40.91%      27.000us      27.000us             1
#       aten::empty_strided         3.79%      11.724us         3.79%      11.724us      11.724us      15.000us        22.73%      15.000us      15.000us             1
#           cudaEventRecord         5.22%      16.136us         5.22%      16.136us       2.689us       0.000us         0.00%       0.000us       0.000us             6
#           cudaMemcpyAsync         4.32%      13.360us         4.32%      13.360us      13.360us       0.000us         0.00%       0.000us       0.000us             1
#          cudaLaunchKernel        74.95%     231.796us        74.95%     231.796us       2.972us       0.000us         0.00%       0.000us       0.000us            78
#     cudaDeviceSynchronize         2.21%       6.822us         2.21%       6.822us       6.822us       0.000us         0.00%       0.000us       0.000us             1
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 309.247us
# Self CUDA time total: 66.000us
#
# attn values sanity check: True
# ------------ vector add on size 8192 ------------------------------------
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::clone         4.44%      16.765us        16.37%      61.855us      61.855us      22.000us        33.33%      66.000us      66.000us             1
#               aten::copy_         2.83%      10.686us         6.47%      24.457us      24.457us      28.000us        42.42%      28.000us      28.000us             1
#       aten::empty_strided         3.24%      12.248us         3.24%      12.248us      12.248us      16.000us        24.24%      16.000us      16.000us             1
#           cudaEventRecord         4.50%      17.015us         4.50%      17.015us       2.836us       0.000us         0.00%       0.000us       0.000us             6
#           cudaMemcpyAsync         3.65%      13.771us         3.65%      13.771us      13.771us       0.000us         0.00%       0.000us       0.000us             1
#          cudaLaunchKernel        79.58%     300.637us        79.58%     300.637us       3.304us       0.000us         0.00%       0.000us       0.000us            91
#     cudaDeviceSynchronize         1.76%       6.651us         1.76%       6.651us       6.651us       0.000us         0.00%       0.000us       0.000us             1
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 377.773us
# Self CUDA time total: 66.000us
#
# attn values sanity check: True
# ------------ vector add on size 16384 ------------------------------------
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::clone         3.68%      15.736us        15.56%      66.492us      66.492us      20.000us        28.57%      70.000us      70.000us             1
#               aten::copy_         2.43%      10.371us         7.29%      31.163us      31.163us      35.000us        50.00%      35.000us      35.000us             1
#       aten::empty_strided         2.74%      11.722us         2.74%      11.722us      11.722us      15.000us        21.43%      15.000us      15.000us             1
#           cudaEventRecord         3.67%      15.701us         3.67%      15.701us       2.617us       0.000us         0.00%       0.000us       0.000us             6
#           cudaMemcpyAsync         4.87%      20.792us         4.87%      20.792us      20.792us       0.000us         0.00%       0.000us       0.000us             1
#          cudaLaunchKernel        73.69%     314.877us        73.69%     314.877us       2.999us       0.000us         0.00%       0.000us       0.000us           105
#     cudaDeviceSynchronize         8.92%      38.113us         8.92%      38.113us      38.113us       0.000us         0.00%       0.000us       0.000us             1
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 427.312us
# Self CUDA time total: 70.000us
#
# attn values sanity check: True
# ------------ vector add on size 32768 ------------------------------------
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::clone         3.18%      15.847us        11.77%      58.719us      58.719us      20.000us        32.26%      62.000us      62.000us             1
#               aten::copy_         2.03%      10.107us         4.72%      23.537us      23.537us      27.000us        43.55%      27.000us      27.000us             1
#       aten::empty_strided         2.34%      11.673us         2.34%      11.673us      11.673us      15.000us        24.19%      15.000us      15.000us             1
#           cudaEventRecord         3.19%      15.908us         3.19%      15.908us       2.651us       0.000us         0.00%       0.000us       0.000us             6
#           cudaMemcpyAsync         2.69%      13.430us         2.69%      13.430us      13.430us       0.000us         0.00%       0.000us       0.000us             1
#          cudaLaunchKernel        85.04%     424.107us        85.04%     424.107us       3.534us       0.000us         0.00%       0.000us       0.000us           120
#     cudaDeviceSynchronize         1.54%       7.665us         1.54%       7.665us       7.665us       0.000us         0.00%       0.000us       0.000us             1
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 498.737us
# Self CUDA time total: 62.000us
#
# attn values sanity check: True
# ------------ vector add on size 65536 ------------------------------------
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::clone         2.31%      16.087us         8.56%      59.537us      59.537us      19.000us        30.16%      63.000us      63.000us             1
#               aten::copy_         1.47%      10.222us         3.37%      23.466us      23.466us      28.000us        44.44%      28.000us      28.000us             1
#       aten::empty_strided         1.71%      11.869us         1.71%      11.869us      11.869us      16.000us        25.40%      16.000us      16.000us             1
#           cudaEventRecord         2.44%      16.952us         2.44%      16.952us       2.825us       0.000us         0.00%       0.000us       0.000us             6
#           cudaMemcpyAsync         1.90%      13.244us         1.90%      13.244us      13.244us       0.000us         0.00%       0.000us       0.000us             1
#          cudaLaunchKernel        55.08%     383.287us        55.08%     383.287us       2.818us       0.000us         0.00%       0.000us       0.000us           136
#     cudaDeviceSynchronize        35.10%     244.249us        35.10%     244.249us     244.249us       0.000us         0.00%       0.000us       0.000us             1
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 695.910us
# Self CUDA time total: 63.000us
#
# attn values sanity check: True
# ------------ vector add on size 16777216 ------------------------------------
# <ipython-input-10-fa574b21b1ac>:11: FutureWarning: The attribute `use_cuda` will be deprecated soon, please use ``use_device = 'cuda'`` instead.
#   with torch.autograd.profiler.profile(use_cuda=True) as prof:
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::clone         0.01%      25.207us         0.04%      73.172us      73.172us      10.000us         1.80%     557.000us     557.000us             1
#               aten::copy_         0.01%      10.397us         0.01%      22.963us      22.963us     545.000us        97.85%     545.000us     545.000us             1
#       aten::empty_strided         0.01%      17.265us         0.01%      17.265us      17.265us       2.000us         0.36%       2.000us       2.000us             1
#           cudaEventRecord         0.01%      21.269us         0.01%      21.269us       3.545us       0.000us         0.00%       0.000us       0.000us             6
#           cudaMemcpyAsync         0.01%      12.566us         0.01%      12.566us      12.566us       0.000us         0.00%       0.000us       0.000us             1
#          cudaLaunchKernel         0.44%     817.822us         0.44%     817.822us       2.726us       0.000us         0.00%       0.000us       0.000us           300
#     cudaDeviceSynchronize        99.51%     183.814ms        99.51%     183.814ms     183.814ms       0.000us         0.00%       0.000us       0.000us             1
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 184.719ms
# Self CUDA time total: 557.000us
#
# attn values sanity check: True
